# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyasathyanarayana1/AI_Lab/blob/main/AIlabexam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys


board = {i: ' ' for i in range(1, 10)}
players = ['X', 'O']
current_player = players[0]


WINNING_COMBOS = [

    (1, 2, 3),
    (2, 3, 4),
    (3, 4, 5),
    (6, 7, 8),

    (1, 6, 9),
    (3, 7, 9),
    (5, 8, 0),
]


WINNING_COMBOS = [

    (1, 2, 3), (2, 3, 4), (3, 4, 5),
    (6, 7, 8),

    (1, 6, 9),
    (3, 7, 9),
    (5, 8, 9),
]

def print_board(board):
    print(f"      {board[9]}      ")
    print(f"    {board[6]} {board[7]} {board[8]}    ")
    print(f"  {board[1]} {board[2]} {board[3]} {board[4]} {board[5]}  ")
    print("\n")

def check_win(board, player):
    for combo in WINNING_COMBOS:
        if all(board[pos] == player for pos in combo):
            return True
    return False

def check_draw(board):
    return all(cell != ' ' for cell in board.values())

def play_game():
    global current_player
    while True:
        print_board(board)
        try:
            move = int(input(f"Player {current_player}, enter your move (1-9): "))
            if move not in board or board[move] != ' ':
                print("Invalid move. Try again.")
                continue
        except ValueError:
            print("Invalid input. Please enter a number.")
            continue

        board[move] = current_player

        if check_win(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins")
            break
        if check_draw(board):
            print_board(board)
            print("It's a draw")
            break


        current_player = players[1] if current_player == players[0] else players[0]

if __name__ == "__main__":
    play_game()
# Out:
#
#
#
#
#
# Player X, enter your move (1-9): 1
#
#
#   X
#
#
# Player O, enter your move (1-9): 2
#
#
#   X O
#
#
# Player X, enter your move (1-9): 3
#
#
#   X O X
#
#
# Player O, enter your move (1-9): 4
#
#
#   X O X O
#
#
# Player X, enter your move (1-9): 5
#
#
#   X O X O X
#
#
# Player O, enter your move (1-9): 6
#
#     O
#   X O X O X
#
#
# Player X, enter your move (1-9): 7
#
#     O X
#   X O X O X
#
#
# Player O, enter your move (1-9): 8
#
#     O X O
#   X O X O X
#
#
# Player X, enter your move (1-9): 9
#       X
#     O X O
#   X O X O X
#
#
# Player X wins
